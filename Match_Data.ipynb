# %% [markdown]
# ### This notebook makes an effort to determine exactly what subjects, and what input datastream was used in https://www.biorxiv.org/content/10.1101/2020.05.08.084707v1

# %%
from glob import glob 
import pandas as pd
import csv
import numpy as np
import chardet
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We analyzed data from 7,321 of the 11,878 participants. This subset resulted from the
# following exclusion, which attempted to eliminate incomplete data or data that were already
# flagged as problematic by the ABCD study organizers. First, we attempted to download 8,811
# participants from the “FastTrack Recommended Active Series” from the NIMH Data Archive,
# which has gone through some quality assurance for the associated imaging files by the ABCD
# study organizers. Of these, 8,776 files were successfully downloaded, but a subset did not
# include stop-signal data, leaving ​ 7,906 subjects. Of these, only 7,347 included ​ summary scores
# from the Stop Signal Task in the ABCD Data Release 2.0. Finally, 26 subjects were removed who did not have two complete runs with 180 trials each, leaving us with a total of 7,321
# complete datasets.

# %% [markdown]
# Claim 1: First, we attempted to download 8,811 participants from the “FastTrack Recommended Active Series” from the NIMH Data Archive
#
# As of 5/13/2020, the recommended active series (for all modalities) has 10709 subjects avaliable, and alternate values based on when extra subjects were added would be 10404 before oct 2019, 9315 before sept 2019, and 8151 before aug 2019.
#
# Alternatively, they could have tried to select just the fMRI fast track reccomended data:
# This starts with 10390 subejcts avaliable as of 5/13/2020, goes down to 10098 as of oct 2019, down to 9032 as of sep 2019, and then down to 7904 as of oct 2019.
#
# Lastly, they could have tried to select just the SST data:
# As of may 2020 there are 9181 subjects avaliable, and assuming downloaded before oct 2019, there are 8279 subjects avaliable.
#
# In summary, it is unclear what 8,811 participants cam from - but lets assume they did as they said and downloading the full "FastTrack Recommended Active Series"

# %% [markdown]
# From https://github.com/mckenziephagen/ABCD_Stop_Signal/blob/eaf3c8d500971ba8c458c59f743fd3040eeb1133/scripts/General/s3_keys.ipynb
#
# We will try to re-create what they did to download the data from this above deleted script.

# %%
def load_img_manifest(name):
    
    # This is just where my AWS downloader saved the manifests, and to keep things
    # simple I would just rename them + keep them in the same folder
    df = pd.read_csv('/home/sage/AWS_downloads/' + name, sep='\t', error_bad_lines=False,
                     engine = 'python', quoting=csv.QUOTE_NONE,
                     header=[0]).replace('"','', regex=True)
    df = df.drop(df.index[0], axis=0)
    return df

# %% [markdown]
# Specifically what is done below is that I just try downloading the image manifest for a number of different permutations of possible reccomended active series fasttrack data from nda. I.e., 'all' is if you download all of the fasttrack data, for all imaging data, all_minus1 would be downloading the same but without the very last added data source, minus 2 would be without the last 2, 'frmi' would be if you downloading just the reccomended active series frmi datam etc..., and 'fast' is downloading all the subjects from the just fasttrack data (no reccomended active series flag), and on and on. The details don't reallyt matter as you'll see below.

# %%
df1 = load_img_manifest('all.txt')
df2 = load_img_manifest('all_minus1.txt')
df3 = load_img_manifest('all_minus2.txt')
df4 = load_img_manifest('all_minus3.txt')
df5 = load_img_manifest('fmri.txt')
df6 = load_img_manifest('just_sst.txt')
df7 = load_img_manifest('fast.txt')
df8 = load_img_manifest('fast_minus1.txt')
df9 = load_img_manifest('fast_minus2.txt')
df10 = load_img_manifest('null.txt')

# %%
all_dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]

# %%
for df in all_dfs:
    print(len(df), len(df['"subjectkey"'].unique()))
# Out:
# 301838 10709
# 296738 10673
# 279281 10651
# 260770 10637
# 119443 10390
# 22489 9181
# 360099 11769
# 351299 11767
# 332633 11763
# 301838 10709

# %% [markdown]
# None match the length, 250331, as seen in the s3_keys script... Interesting ? And we still dont match the number of subjects

# %% [markdown]
# Rest of steps of steps from original analysis

# %% [markdown]
# image_descriptions = ['ABCD-SST-fMRI']
#
# s3_df = pd.DataFrame()
# for task in image_descriptions:
#     s3_df = s3_df.append(sub_df[sub_df.iloc[:, 11] == task])
#
# s3_df = s3_df[s3_df['"visit"'] == 'baseline_year_1_arm_1']
#
# with open('all_SST_s3s.txt', 'w') as file:
#     for i in s3_df['"image_file"']:
#         file.write(i  + "\n")

# %% [markdown]
# Convert the above to just: filten by task then eventname

# %%
for df in all_dfs:
    df = df[df['"image_description"'] == 'ABCD-SST-fMRI']
    df = df[df['"visit"'] == 'baseline_year_1_arm_1'] 
    
    print(df.shape, len(df['"subjectkey"'].unique()))
# Out:
# (17243, 112) 8811
# (17243, 112) 8811
# (17176, 112) 8777
# (16854, 112) 8618
# (17243, 112) 8811
# (17243, 112) 8811
# (20296, 112) 10166
# (20296, 112) 10166
# (20220, 112) 10131
# (17243, 37) 8811

# %% [markdown]
# At last 8811! We have have where they got the number! Next, download the data as they did.

# %%
# Lets save our keys to download as the 1st one, which I'm confident now is the one they used
s3_df = all_dfs[0]

with open('all_SST_s3s.txt', 'w') as file:
    for i in s3_df['"image_file"']: 
        file.write(i  + "\n")

# %% [markdown]
# Specifically, after these keys are saved, the nda_tools download script is used to perform the download
#
# the command: downloadcmd all_SST_s3s.txt -t
# is run.
#
# Then to extract the output the following script is submitted to the UVM VACC cluster - which is designed to be a parrellizable to an arbitrary number of jobs script that extracts the event file from downloaded raw fast track data, and then deleted the original tar file

# %%
import tarfile, os, random

def extract_event(file, dr):

    tar = tarfile.open(file, "r:gz")
    for m in tar.getmembers()[::-1]:

        if 'EventRelatedInformation' in m.name:

            name = m.name
            new_dr = os.path.join(dr, '/'.join(name.split('/')[:-1]))
            os.makedirs(new_dr, exist_ok=True)

            file_loc = os.path.join(dr, name)
            event_info = tar.extract(m, dr)

            os.remove(file)
            break

dr = '/users/s/a/sahahn/SST_Data'
download_dr = '/users/s/a/sahahn/AWS_downloads'

folders = os.listdir(download_dr)
folders = [os.path.join(download_dr, folder) for folder in folders]
random.shuffle(folders)

for folder in folders:
    files = os.listdir(folder)
    files = [os.path.join(folder, file) for file in files]

    files = [file for file in files if file.endswith('.tgz')]
    random.shuffle(files)

    for file in files:
        if file in [os.path.join(folder, f) for f in os.listdir(folder)]:
            os.rename(file, file + '-extracting')
            extract_event(file + '-extracting', dr)

# %% [markdown]
# ## Part 2 - creating the merged / concated event file
#
# The next step in tracking down the number of subjects comes from:
#
# "Of these, 8,776 files were successfully downloaded, but a subset did not
# include stop-signal data, leaving ​ 7,906 subjects. Of these, only 7,347 included ​ summary scores
# from the Stop Signal Task in the ABCD Data Release 2.0. Finally, 26 subjects were removed who did not have two complete runs with 180 trials each, leaving us with a total of 7,321
# complete datasets.", we will also reference https://github.com/mckenziephagen/ABCD_Stop_Signal/blob/eaf3c8d500971ba8c458c59f743fd3040eeb1133/scripts/SST_manuscript/concat.ipynb
# In this notebook, which is another deleted notebook.
#
#
#
# ## Issue 1
#
# What I did was tried to download the same set of files they did. In my download, 8809, files were both successfully downloaded + have the event information file (just SST data). So, apparently 33 subjects in their download just didn't work? I mean, some didn't work in my download, but 33 is a bit of a different (granted the caveat here is that I only kept the event file info, maybe they had already filtered for missing stop-signal data??
#
#
#
# I further put the sst event files in their original directory structure w/ even the saming naming as seen in the above notebook, SST_Data, for consistency w/ their work.

# %%
from glob import glob 
import pandas as pd
import csv
import numpy as np
import chardet
import os

# %%
# This file globbing is the one they may have used based on the shared script
subs = list(set([i.split('-')[1].split('/')[0]
                 for i in glob('data/SST_Data/sub-*/ses-baselineYear1Arm1/func/*SST*.txt')]))
len(subs)
# Out:
# 8146

# %%
main_dr = 'data/SST_Data/'
subjects = os.listdir(main_dr)
print(len(set(subjects)))
# Out:
# 8808

# %% [markdown]
# Why is this number different from the number of subjects in the directory?
#
# A little investigation reveals this is due to some are saved as .csv, lets look at it more closely

# %%
n_mixed = 0

for subject in subjects:
    sub_dr = os.path.join(main_dr, subject)
    sessions = os.listdir(sub_dr)
    
    if 'ses-baselineYear1Arm1' not in sessions:
        print(sessions)
        
    else:
        session_dr = os.path.join(sub_dr, 'ses-baselineYear1Arm1')
        f_files = os.listdir(session_dr)
        
        if 'func' not in f_files:
            print(f_files)

        else:
            f_dr = os.path.join(session_dr, 'func')
            files = os.listdir(f_dr)
            if 'SST' not in files:
                for file in files:
                    if '.txt' not in file or 'SST' not in file:
                        print(file)
                        
                # How many cases where 1 txt 1 csv
                num_txt = len([f for f in files if '.csv' in f])
                num_csv = len([f for f in files if '.txt' in f])
                
                if num_txt == 1 and num_csv == 1:
                    n_mixed += 1
# Out:
# ABCD-SST-fMRI_run-20170616154139-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170616154824-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180625103553-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180625102736-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008162852-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008162255-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180523174759-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180523175418-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180726151456-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180726152144-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119105057-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119105833-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160926160659-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160926161429-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825120007-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825120631-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161115194643-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180523171837-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180523172533-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170805104535-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170805105148-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180901130107-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180901125437-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526111504-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526112157-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170710173243-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008173844-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008174609-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821160609-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821161253-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181018134625-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181018135248-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120092159-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120091445-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609141019-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609141737-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609151233-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609151903-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731182444-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731183155-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180605105301-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180605104645-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821162707-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821163343-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161015104131-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161015104805-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824104252-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824104919-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180729112222-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180729111554-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180504161907-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180307132630-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170424143256-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170424142632-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180828103755-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180828103156-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622142455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622143106-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526162755-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526163430-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180710104207-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180710103542-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808151243-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808150536-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008110852-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008110155-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513111121-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513110505-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161109165142-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161109165853-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180419144137-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180419144749-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123164354-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123163729-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170817113749-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170817113127-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180604105412-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180604110025-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180814104741-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180814105349-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824113400-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824112553-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414163226-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414163853-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613163842-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613163116-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731152521-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731153207-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170304155533-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926172419-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926173029-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180915113455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180915114133-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926162632-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926163303-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630140341-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630140951-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180802134238-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180802134907-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180928121857-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180928122608-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006140011-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006135345-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829161124-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829161731-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120160659-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120160002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120153635-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170114130605-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170114131226-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161215173717-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161215174517-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160929183151-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160929185200-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008132103-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008131419-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170918174216-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170918174856-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009181617-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009182223-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815161642-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815161019-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170506142036-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170506141418-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170830180418-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170830181107-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009102526-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009103139-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170408111331-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170408110649-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180830133628-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180830133017-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170110171927-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170110172547-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180316134125-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180316133522-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180822143539-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180822142856-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160924125401-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160924130248-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825114238-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825113617-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160924114304-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160924113524-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180921160059-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180921155315-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181022185559-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181022184906-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161024122741-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161024123454-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180712115755-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180712120506-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801142442-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801143051-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180314160143-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180314160813-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731112925-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731113544-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180517155757-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180517155018-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731102727-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731103354-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170311150318-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170208191128-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180816181244-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180816180544-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170712164812-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123133902-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123133144-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161029125150-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161029124510-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180327102840-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180327102225-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161026143309-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160917143702-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160917144326-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414133045-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414132423-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180813105758-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180813112129-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180813111518-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112141512-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112140758-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829105638-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829104753-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170506113950-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621113601-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621112948-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926125656-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180512142917-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180512142246-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180910152748-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180910153425-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004122226-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004121426-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714112509-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714113139-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728142735-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728143426-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180528123123-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180528123753-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170619140223-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170619135508-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613110408-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613111022-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005175647-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005174910-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180426112658-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180426111943-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121143302-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121143953-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425181337-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425182002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170428141907-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170428142827-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170428142535-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161007171132-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161007170346-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815185232-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815184550-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180605145517-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180605150133-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022160845-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170116143111-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170116142426-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008151926-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008152743-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161116181706-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161116181008-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180404134756-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180404135407-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180826151847-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180826152557-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170706115451-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170706114806-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180918174142-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180918173418-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170828122901-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170828122217-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170630130524-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170630125819-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170324173425-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170324174108-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171016171015-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171016171718-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161113093457-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613125931-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613125313-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005153735-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005154428-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170330110503-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180529101755-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180529102423-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622141039-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622140332-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180804141606-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180804142327-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609123313-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609123933-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161108184058-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180911140726-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180911140037-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170726144645-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170726145355-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180703114742-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180703114108-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180721114540-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180721113850-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180811112934-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180811112059-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170203190403-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170203191030-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022115059-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022115813-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170822120529-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170822121139-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170307142456-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170307141759-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180806112522-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180806113204-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161203164855-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161203165616-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121142833-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121143603-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824135530-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180824140310-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180606190101-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180606185447-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170825131829-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725095933-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725095238-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180110180143-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180110175511-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170713111515-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170713110703-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170426143032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170426142341-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161115171404-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161115170602-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180411165444-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180411170102-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170612134618-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170612133925-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180908111208-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180908111840-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170223134013-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170223134653-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170228174736-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171018113309-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180915111533-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180915110913-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180727125439-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180727124705-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180903143348-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180903142708-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120134639-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120135420-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180826115047-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180826115742-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120161311-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120162048-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180620112306-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180620111542-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627143547-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627144200-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180906180814-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180906181519-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161202193544-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161202192924-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613124034-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613124702-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002163057-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002163737-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161106105734-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161106105025-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181003161553-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181003162245-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711163201-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711163844-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820153658-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820154343-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180116111939-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170624134132-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170624134818-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180607111527-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180607110856-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010141226-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010140608-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180830154209-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180830154831-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821122323-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821121636-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170401141642-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170401141015-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180501180908-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180501181551-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161203110902-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161203111554-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170206180421-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170206175708-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122150702-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122151456-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008165110-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008164221-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180119161356-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180119162005-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171018153840-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171018154511-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170318163712-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170318164406-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009132719-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181009131938-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180831141400-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180831140734-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161017140125-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714123224-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714123906-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170617112517-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170617113204-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171025175049-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119150329-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119145431-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180807102912-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180807102249-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180720160014-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180720155342-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180530172327-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180530171556-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180831141943-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180831141209-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180629164355-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180629163747-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002141934-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002141317-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180429142841-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180429143516-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180430142054-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180430141328-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801151803-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801152455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801181718-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801182325-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627182141-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627181527-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119151448-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119152118-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180908140713-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180908141401-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170629114124-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170315162245-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170315162916-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180515163155-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180515163907-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170805141609-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170805140739-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171024172313-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171024173001-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161128164214-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170715161452-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170715162134-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602142324-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602143003-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821123214-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821123913-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180910110005-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180910105352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180924110539-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180924111224-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180616111247-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170731144020-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170731144706-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513144744-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513144103-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180720151250-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180720150600-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161001104127-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161001103455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002182537-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181002183217-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613145227-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180613145909-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180421140311-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180421140954-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180724155008-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180724154352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181019132601-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181019133251-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161026184204-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161026183413-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181012172404-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181012171753-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180618112717-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180618113352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170630110626-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170728114435-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170728115122-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180710154732-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180710154059-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170228113438-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170228112754-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161108180856-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161108181528-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821100522-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170821101210-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621143002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621142332-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180422110810-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180422111449-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825160713-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825155843-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180928161416-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180928162032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170629132136-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170629132833-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180707141641-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180707142408-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180516182858-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180516182203-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013121025-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013121647-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170809160831-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170809160108-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170831174336-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829154312-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829154929-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827112944-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827113727-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180719115537-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180719120143-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180421112139-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180421111053-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170615173527-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170615172806-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180611123159-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180611123903-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180331113037-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180331113705-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181001182450-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181001181827-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180727131333-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180727131943-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820122358-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820121710-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180407110523-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180407111140-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170624160921-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170624160218-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808134933-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808135542-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170327195832-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170327195218-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180707114226-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180707114921-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825102355-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825103011-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505135719-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505140347-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170306115754-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170306120413-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180601151757-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180601152421-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180905135845-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180905134839-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180125095352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180125100102-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829173118-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829173752-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180612101146-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180612100533-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180508172253-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180508172955-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829103302-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829102607-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170227194047-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161116112242-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171014142328-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171014143005-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711132918-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711133542-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171104113812-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161105105307-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161105110011-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011174414-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011173733-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170817102121-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170817102801-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161126110002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161126110639-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180628163408-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180628162556-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004115619-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004120312-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180907164218-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180907164822-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714110726-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714111337-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180612150703-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180612150032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160927165922-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160927165110-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170428173945-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602114203-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602113528-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121143341-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161121144031-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829132916-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170829132232-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180809142245-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180809143003-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725144831-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725144202-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170301140740-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170301135908-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180828140556-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180828134836-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180828135934-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161027142146-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161027142932-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815183723-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815183059-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180917194209-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180917193532-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161219181146-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161219180459-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181015160829-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181015161500-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627111254-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627110640-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005121524-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005120903-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505164913-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505164233-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825144024-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825143335-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160919155729-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160919155402-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160919154742-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180705135757-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180705140436-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181018185451-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181018184828-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160909194520-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160909193851-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180906150009-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180906150725-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630110916-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630110255-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122184710-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122185414-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829183929-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180829184549-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180316155545-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180316160202-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161110171622-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161110170557-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820154629-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180820155336-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122172428-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161122173159-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425163708-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425163008-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170520113935-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170520114542-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180901180313-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180901181002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161221175326-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161221174618-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180519112319-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180519111614-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170114162327-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170114161707-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180721154041-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180721153424-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180623114811-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180623114130-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526142802-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180526142045-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170515173851-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170515174507-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180411154209-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180423113042-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180423113723-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180426140149-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022121801-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022122530-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161216173813-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161216173104-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181016183104-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181016182351-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414151026-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414150355-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022133236-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161022132432-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180904135908-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180904134759-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180608172845-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180608172234-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513105616-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170513110306-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170608161925-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170608161204-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170712143258-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170421180558-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170421181227-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180329114122-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180329113509-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827111846-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827112508-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180803115252-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180803115922-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180929121433-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180929122046-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602111957-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602112724-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622161935-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622162604-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170520163058-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170520163716-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180905141358-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180905140535-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180430165325-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180430164618-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170303140607-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170303141322-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170801144758-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170801144103-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119164223-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119164938-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714134824-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180714135521-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180428140651-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180428141329-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161219173015-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180310113955-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180310114714-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180723173632-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180723174312-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161221155656-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161221160530-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170623101203-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170623101901-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725122928-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725122312-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180422140028-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180422135355-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180716145154-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180716145752-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825115952-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180825120626-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161114181010-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161114181741-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180530113017-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180530113627-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180426155919-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180426155205-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010144433-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010145152-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180716111213-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180716111829-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123172643-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161123173316-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180629134616-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180629135235-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602135505-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180602140124-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180813102100-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180813101358-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180805113649-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180805114536-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808130617-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808125920-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170324160424-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180919183948-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180919184613-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161114120338-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161114120959-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927183755-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927183148-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171020141446-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808152001-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180808152624-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728113613-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728112938-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731141405-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180731140748-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006105539-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006110204-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170307161512-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170307162227-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161222181348-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161222182032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161213194146-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161213194905-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171014113956-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171014114738-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170204115956-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801121802-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180801122419-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180924103637-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180924104306-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180822184016-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180822183412-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011114845-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011114115-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180702110625-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180702105953-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180625114452-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180625113803-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180606174814-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180606174105-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180415164042-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180415164819-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711171842-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711171138-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161021105558-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161021110311-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004103725-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181004103058-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926191151-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180926190507-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170218112922-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170218112256-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161019112529-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161019111753-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180804104504-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180804103711-EventRelatedInformation.csv
# ...
# ABCD-SST-fMRI_run-20161201172127-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630115828-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180630120543-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180910114211-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181115172348-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181115173008-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711110520-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180711105844-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008170249-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161008165810-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827153329-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827154005-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170708135901-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170708135135-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013101655-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013101032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161026114436-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161026113653-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170714154018-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170714153318-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180222103846-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180222103203-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160928194105-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161217163948-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161217163257-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180315134640-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180315135340-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180619113225-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180619112608-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005153842-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181005154503-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170816102946-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170816103629-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180514183414-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180514184043-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119160826-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119160115-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180317121102-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180317121733-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161012163717-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180922105036-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160922123529-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160922122802-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627123206-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180627123835-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821161336-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821160719-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827173052-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827172455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170311142554-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170311143219-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180705155002-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180705155619-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120155658-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120154955-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171020113112-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171020113758-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161203131129-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119163901-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161119164559-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180417102407-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180417101752-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180317144718-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180317145325-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180404112322-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180404112929-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011122331-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181011122945-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170804112015-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170804111331-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180626134733-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180626135440-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161207163849-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161207163152-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180814113551-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180814114213-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161118171659-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161117161536-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161117162229-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010172719-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181010173339-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161007153657-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161007154403-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180321180509-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180321175812-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180912175932-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180912181001-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170911174823-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170911174147-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013153304-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181013153942-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821113733-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180821112935-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160924173339-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927123637-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927123032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180519160724-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171027164152-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171027164820-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180911103114-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180911102455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170621161614-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170621160957-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180509181730-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008135752-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181008140515-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170906175445-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170906174754-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180616114036-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180616114639-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180615112415-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180615113119-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180703152842-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180703153451-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180326111819-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180326111207-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170725161222-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170725161920-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180528143140-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180528142505-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170628150740-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180803154725-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180803154041-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170815142814-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170815143525-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414144515-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414145202-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170320184050-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728112336-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180728113032-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170628174520-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170628173835-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161021123310-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161021124054-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170914173836-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170726112112-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170726112852-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170519174626-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170519175454-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161202173532-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161202174316-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622164447-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180622165057-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180616142106-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180616142725-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180929110727-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180929111520-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170814122202-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170814122856-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180607134605-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180607133947-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161106174709-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161106175442-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170801164729-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170801164050-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160908173816-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160908173045-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120135512-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120140320-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180413164753-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180413165451-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170717165237-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170717164603-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180415142836-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180415142136-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112162721-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112163437-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180902153112-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180902153751-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006112735-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181006113433-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170619163454-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170619162816-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180620192325-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180620191700-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181019125423-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181019130213-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181012113622-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181012112914-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621100458-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621101242-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170610114040-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170610113400-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170518174420-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170518173734-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170826141252-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170826142043-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621161714-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180621162327-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120151121-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161120151741-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161010123850-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161010123221-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161105144736-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161105144003-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170429135130-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170429134508-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170707090810-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170707091528-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112141709-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161112142455-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170227180020-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170227180632-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505110815-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180505105913-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180406172600-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180406173216-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181003114103-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20181003113445-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180328174313-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180328173544-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161027180740-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171031100207-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20171031100820-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180806113342-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180806112732-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170210165333-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170227160257-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170227155603-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170427113122-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170427112652-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725184037-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180725184815-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414121450-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180414120736-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827134255-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180827133532-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609165252-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180609164536-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425135527-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180425134834-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180706111334-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180706112012-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160918102026-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20160918102654-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170614171222-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170614171914-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180712142633-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180712143352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180423112054-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180423112715-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170204131114-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170204130352-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927182625-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180927181908-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180802102818-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180802102058-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161128172052-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161128172930-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180604174411-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180604175116-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180429111807-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180429112508-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815153621-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180815154330-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161019172113-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20161019171339-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170713132617-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180518171252-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20180518171920-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170815095241-EventRelatedInformation.csv
# ABCD-SST-fMRI_run-20170815095920-EventRelatedInformation.csv

# %%
# So this is the number of subjects with 1 .txt eventfile and .csv
n_mixed
# Out:
# 10

# %%
missed_subs = list(set([i.split('-')[1].split('/')[0]
                   for i in glob('data/SST_Data/sub-*/ses-baselineYear1Arm1/func/*SST*.csv')]))
len(missed_subs)
# Out:
# 683

# %% [markdown]
# ## Issue 2
#
# a number of subjects were systematically excluded before their event related information was saved as a csv... with another 10 cases where it appeared there was only 1 valid run, but only because their was one event info .csv and one .txt

# %%
event_files = glob('data/SST_Data/sub-*/ses-baselineYear1Arm1/func/*SST*.txt')
missed_event_files = glob('data/SST_Data/sub-*/ses-baselineYear1Arm1/func/*SST*.csv')
len(event_files), len(missed_event_files)
# Out:
# (15922, 1314)

# %%
# I add this function, because eventfiles are duplicated in the fast track data
def remove_duplicates(event_files):
    
    subjs = np.array([e.split('/')[2] for e in event_files])
    to_delete = []

    for s in subjs:
        inds = np.where(subjs == s)[0]
        if len(inds) > 1:
            for i in inds[1:]:
                to_delete.append(i)
                
    to_delete = list(set(to_delete))
    event_files = np.delete(np.array(event_files), to_delete)
    
    return list(event_files)

# %%
# Remove duplicates, as see there are ~twice as many
event_files = remove_duplicates(event_files)
missed_event_files = remove_duplicates(missed_event_files)

len(event_files), len(missed_event_files)
# Out:
# (8146, 683)

# %%
def get_encoding(file): 
    """
    retrieves character encoding of file to be passed to 
    pd.read_csv()
    """
    with open(file, mode = "rb") as f: 
        rawdata = f.read()
        return chardet.detect(rawdata)['encoding']

# %% [markdown]
# The below chunk of code is slightly modified from their shared code on this merging, I just added a try expect block to catch failed files, and a check to add 'weird' files. Extremely percise language, I know

# %%
i=0

dfp = []
failed_files = []
weird_files = []

for file in event_files: 
    subj_id = file.split('/')[2].split('-')[1].replace('NDAR', 'NDAR_')
    encoding = get_encoding(file)
    
    # In a number of cases, the original code fails a number of times, lets' save these files
    # to look at more closely
    try:
        
        df = pd.read_csv(file, sep = '\t', encoding = encoding)
        
        if df.columns[0] != 'ExperimentName': #to fix header differences
            df = pd.read_csv(file, sep = '\t', skiprows=[0], encoding = encoding)
            
        df['src_subject_id'] = subj_id
        
        if 'Go.RESP' not in list(df):
            weird_files.append(file)
        else:
            dfp.append(df)
    
    except:
        failed_files.append(file)
        
    i+=1

# %%
event_df = pd.concat(dfp, sort=True, axis=0)

for col in event_df.columns:
    if 'Unnamed' in col or 'task' in col or 'Test' in col or 'Wait' in col:
        del event_df[col]
        
del dfp # Save memory   

event_df.to_csv('merged_data/full_SST_concat.csv')

# %% [markdown]
# Notably some of the weird and bad files might be salvagable... likewise we have still been just ignoring all the csvs.
#
# The provided loading code (caveat: not officially provided, s.t., the actual final version could have done something different, i.e., the referenced code only goes through this process on 100 event files, s.t., when they actually ran this on all the subjects they very likely encountered a simmilar error - but who knows if they fixed it or not) fails for 26 files

# %%
## My artesinal take on creating a loading function robust to the weird errors

def load_event_file(file, sep='\t'):
    subj_id = file.split('/')[2].split('-')[1].replace('NDAR', 'NDAR_')
    
    encoding = get_encoding(file)
    try:
        df = pd.read_csv(file, sep =sep, encoding = encoding)
    except:
        try:
            df = pd.read_csv(file, sep =sep, encoding = encoding, skiprows=[0, 1])
        except:
            return None

    
    if df.columns[0] == '0-ExperimentName':
        return None
    
    if df.columns[0] != 'ExperimentName':
        df = pd.read_csv(file, sep=sep, skiprows=[0], encoding = encoding)
        
    if '"ExperimentName' in df.columns:
        df = df.rename({'"ExperimentName': 'ExperimentName'}, axis=1)
        
    if df.columns[0] == 'EXPNAME':
        df = pd.read_csv(file, sep=sep, skiprows=[0, 1, 2], encoding = encoding)
        
    try:
        if 'SST' not in df['ExperimentName'][0]:
            return None
    except TypeError:
        return None
    
    df['src_subject_id'] = subj_id
        
    return df

# %%
bad_files = weird_files + failed_files
len(bad_files)
# Out:
# 23

# %%
extra_dfs = []
for file in bad_files:
    df = load_event_file(file)
    
    if df is not None:
        extra_dfs.append(df)

# %%
## Also load the missed event files, w/ more hacky tricks to try and handle all of the weird errors

missed_df = []

for file in missed_event_files:
    
    try:
        df = load_event_file(file, sep=',')
    except KeyError:
        
        try:
            df = load_event_file(file)
        except KeyError:
            
            try:
                df = load_event_file(file, sep='\\t')
            except:
                df = None
    
    if df is not None:
        missed_df.append(df)
# Out:
# /home/sage/anaconda3/envs/home/lib/python3.7/site-packages/ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /home/sage/anaconda3/envs/home/lib/python3.7/site-packages/ipykernel_launcher.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
len(extra_dfs), len(missed_df)
# Out:
# (11, 681)

# %% [markdown]
# Still missing some... but some of the failed files especially are either actually messed up, or in a few cases contain data from a different task. Oh well, stressing about the extact number of subjects is not all that productive.

# %%
extra_df = pd.concat(extra_dfs, sort=True, axis=0)
extra_df.to_csv('merged_data/extra_concat.csv')

missed_df = pd.concat(missed_df, sort=True, axis=0)
missed_df.to_csv('merged_data/missed_concat.csv')

# %% [markdown]
# Lastly, lets do two things, prepare some lower memory versions (i.e., we can get rid of columns which are never used in the remaining analysis), and also we can create all_concat.csv, which represents a merged version of all avaliable data, i.e., the full_SST_concat (my best guess at the subjects they used), with the extra_concat and missed_concat.

# %%
raw_concat = pd.read_csv('merged_data/full_SST_concat.csv', low_memory=False)

used_cols = ['Procedure[SubTrial]', 'Procedure[Trial]', 'Go.RESP', 'Go.CRESP', 'Fix.RESP', 
             'StopSignal.RESP', 'SSD.RESP', 'SSD.RT', 'Stimulus',
             'Go.RT', 'Go.Duration', 'Fix.RT', 'StopSignal.RT', 'StopSignal.Duration',
             'SSDDur', 'NARGUID', 'src_subject_id', 'TrialCode']

raw_concat = raw_concat[used_cols]
raw_concat.to_csv('merged_data/SST_concat.csv')

extra_concat = pd.read_csv('merged_data/extra_concat.csv', low_memory=False)[used_cols]
missed_concat = pd.read_csv('merged_data/missed_concat.csv', low_memory=False)[used_cols]

all_concat =  pd.concat([raw_concat, extra_concat, missed_concat], axis=0)
all_concat.to_csv('merged_data/all_concat.csv')
